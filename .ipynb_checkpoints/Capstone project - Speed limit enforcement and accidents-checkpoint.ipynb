# %% [markdown]
# # Final capstone project: Traffic accidents, nightlife and Speed cameras in Medellín

# %% [markdown]
# ## Introduction
#
# In this project, we will analyze some of the patterns of traffic accidents in Medellín, Colombia.
#
# First, we will check if there is any relationship between traffic accidents and the days of the week. We will see if there exist evidence that supports the hypotesis that there are more serious accidents in the weekends, specially in late night/ early morning hours. Using the foursquare API, we will also check close venues to incidents that involve deaths in those hours, in order to see if there are bars or clubs among those venues, which may suggest drunk drivers causing these deaths.
#
# Finally, we will compare accident data with the geolocation of speed cameras in the city, to see if there are high risk zones that are not properly covered and cant be intervened by the authorities in order to make traffic safer.

# %% [markdown]
# ## Part 1: Traffic accidents and nightlife
# The first step is importing all of the libraries we will use in our notebook:

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
import matplotlib as mpl
import matplotlib.pyplot as plt

from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium 
import io
import datetime as dt
import seaborn as sns

# %% [markdown]
# Our main dataset consists in georeferenced data for all of the reported traffic accidents in Medellín in 2019. This information is made public online by local authorities . The dataset consists of several columns that contain neighborhood, coordinates, class of accident (collision, running overs, etc), date, hour, gravity(if the accident involves injured or dead people), among others. For more information, you can go [here](https://geomedellin-m-medellin.opendata.arcgis.com/datasets/accidentalidad-georreferenciada-2019).
#
# In our dataset, we will include 7 columns:
#
# - **OBJECTID**: an unique ID of the incident.
# - **TIME**: The time of the incident.
# - **CLASS** :Type of event (Choque= colision , Volcamiento= car turned over, Atropello= running over, Caida ocupante= Passenger fell)
# - **GRAVITY**: Seriousness of the incident (Solo daños= Just material damages, Herido= Injured people, Muertos= dead people).
# - **DAY**: Day of the week when the accident took place.
# - **LONGITUDE, LATITUDE**: Coordinates of the accident site.
#
# First, we will import the csv dataset and turn it into a pandas dataframe. We will apply some formating the desired columns:

# %%
url2="https://opendata.arcgis.com/datasets/e132c88e875b429db4c1a3c80b7977da_20.csv"
df_acc=pd.read_csv(url2, skipinitialspace = True)

df_acc['GRAVEDAD'] = df_acc['GRAVEDAD'].str.upper()

df_acc["HORA"]= df_acc["HORA"].str.replace(" ","")
df_acc["HORA"]= df_acc["HORA"].str.replace(".","")
df_acc["HORA"]= df_acc["HORA"].str.upper()
df_acc["DIA_NOMBRE"]= df_acc["DIA_NOMBRE"].str.replace("Á","A")
df_acc["DIA_NOMBRE"]= df_acc["DIA_NOMBRE"].str.replace("É","E")
df_acc["GRAVEDAD"]= df_acc["GRAVEDAD"].str.replace("CON HERIDOS","HERIDO")
df_acc["GRAVEDAD"]= df_acc["GRAVEDAD"].str.replace("CON MUERTOS","MUERTO")


df2=df_acc[["OBJECTID", "HORA","CLASE","GRAVEDAD", "DIA_NOMBRE", "LONGITUD", "LATITUD"]]

df2.columns=["OBJECTID", "TIME", "CLASS","GRAVITY", "DAY", "Longitude", "Latitude"]
df2.head(8)
# Out:
#    OBJECTID        TIME           CLASS     GRAVITY        DAY  Longitude  \
# 0    709812  12:30:00PM          Choque  SOLO DAÑOS  DOMINGO   -75.596093
# 1    709813   6:50:00PM          Choque  SOLO DAÑOS  VIERNES   -75.583161
# 2    709814   8:50:00AM     Volcamiento      HERIDO  MIERCOLES -75.563856
# 3    709815   7:00:00AM          Choque  SOLO DAÑOS  MARTES    -75.576757
# 4    709816  11:30:00AM          Choque  SOLO DAÑOS  MARTES    -75.571897
# 5    709817  12:20:00PM          Choque  SOLO DAÑOS  VIERNES   -75.576737
# 6    709818   3:00:00AM          Choque  SOLO DAÑOS  LUNES     -75.609766
# 7    709819   2:30:00AM  Caida Ocupante      HERIDO  MARTES    -75.563572
#
#    Latitude
# 0  6.256489
# 1  6.250155
# 2  6.250657
# 3  6.268025
# 4  6.202827
# 5  6.207613
# 6  6.257146
# 7  6.293681

# %% [markdown]
# We apply the shape method to check the size of the dataset, which has over 42.000 rows, around 116 accidents per day:

# %%
print (df2.shape)
# Out:
# (42473, 7)

# %% [markdown]
# ### Initial data exploration
# Let's check if the accidents occurr more in certain days of the week:

# %%
df_explor=df2.DAY.value_counts().rename_axis('DAY').reset_index(name='ACCIDENTS')

df_explor
sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))

sns.barplot(x=df_explor.DAY, y=df_explor.ACCIDENTS, color="r")

# %% [markdown]
# Surprisingly, accidents are very well distributed throughout the week, except for sundays, which have less traffic.
#
# We want to see the behavior of the data on weekends, in late night/ early morning hours. We will limit our search to fatal accidents, which are the most grave:

# %%
df_dead= df2[df2.GRAVITY.str.contains("MUERTO")]

df_dead= df_dead.reset_index().drop(columns=['index'])
df_dead['TIME'] = pd.to_datetime((df_dead['TIME']))  
df_dead = (df_dead.set_index('TIME')
          .between_time('22:00:00', '04:00:00')
          .reset_index()
          .reindex(columns=df_dead.columns))

df_dead['TIME']=df_dead['TIME'].dt.time

# %%
search_values=["VIERNES","SABADO","DOMINGO"]
df_wknd= df_dead[df_dead.DAY.str.contains('|'.join(search_values ))].reset_index().drop(columns=['index'])
df_wknd
# Out:
#     OBJECTID      TIME      CLASS GRAVITY        DAY  Longitude  Latitude
# 0     715213  23:35:00     Choque  MUERTO  DOMINGO   -75.549951  6.285445
# 1     717337  04:00:00     Choque  MUERTO  SABADO    -75.570452  6.289219
# 2     718353  00:10:00     Choque  MUERTO  SABADO    -75.575282  6.256743
# 3     718780  02:43:00  Atropello  MUERTO  VIERNES   -75.578548  6.255019
# 4     719435  03:07:00     Choque  MUERTO  SABADO    -75.575113  6.224149
# 5     720486  23:50:00     Choque  MUERTO  SABADO    -75.586753  6.249053
# 6     721169  00:28:00  Atropello  MUERTO  DOMINGO   -75.597292  6.224406
# 7     721672  00:35:00     Choque  MUERTO  SABADO    -75.594462  6.273563
# 8     722205  23:27:00     Choque  MUERTO  SABADO    -75.558421  6.232295
# 9     722653  23:00:00  Atropello  MUERTO  VIERNES   -75.573608  6.255711
# 10    726644  03:50:00     Choque  MUERTO  SABADO    -75.565108  6.242700
# 11    727092  22:40:00     Choque  MUERTO  SABADO    -75.577576  6.254400
# 12    727821  22:10:00     Choque  MUERTO  VIERNES   -75.559726  6.192284
# 13    732135  00:50:00  Atropello  MUERTO  SABADO    -75.611238  6.277925
# 14    732570  00:20:00     Choque  MUERTO  SABADO    -75.585506  6.216870
# 15    733000  00:10:00       Otro  MUERTO  SABADO    -75.569423  6.288415
# 16    734021  00:43:00     Choque  MUERTO  DOMINGO   -75.589317  6.262004
# 17    739479  23:15:00     Choque  MUERTO  SABADO    -75.586443  6.213966
# 18    741512  22:49:00  Atropello  MUERTO  VIERNES   -75.568474  6.243879
# 19    742075  02:50:00     Choque  MUERTO  DOMINGO   -75.564464  6.276728
# 20    742294  02:33:00       Otro  MUERTO  SABADO    -75.578689  6.206569
# 21    748689  00:05:00  Atropello  MUERTO  SABADO    -75.578517  6.240020
# 22    749726  22:49:00     Choque  MUERTO  DOMINGO   -75.577322  6.213905
# 23    756101  02:00:00     Choque  MUERTO  SABADO    -75.568825  6.228088

# %% [markdown]
# As we can see, there are only 24 accidents late night/ early morning on weekends which involve fatal victims. That's around 0.06% of the accidents.
#
# In the next step, we will visualize the location of these fatal accidents in a map:

# %%
address = 'medellín'

geolocator = Nominatim(user_agent="_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Medellín are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Medellín are 6.2443382, -75.573553.

# %%
map_deaths = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lt, lg, cls, day, time in zip(df_dead['Latitude'], df_wknd['Longitude'], df_wknd['CLASS'], df_wknd['DAY'], df_wknd['TIME']):
    label = '{}, {}, {}'.format(cls, day, time)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lt, lg],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(map_deaths)

map_deaths
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can see that fatal accidents occuring on weekend nights are almost randomly distributed along the city, with a slight agglomeration downtown.
#
# We want to check if there are coincidences in the location of the accidents and the presence of clubs, bars, pubs or other sites where alcohol is consumed, in order to suggest the hypotesis that some of this accidents are caused by drunk drivers. For this task, we will use the Foursquare API. First, let's check the credentials:

# %% [markdown]
# Foursquare credentials

# %%
CLIENT_ID = '2YKNS5LEN2NL1IJ0FHAHXMTS11QQSKJDQCVYDFTO3TNMDO0Q' # your Foursquare ID
CLIENT_SECRET = 'SHXP4EQPMHICO3EODBF2HYEOR4RWHOWJ5FMCRS0BAUYNIU0H' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2YKNS5LEN2NL1IJ0FHAHXMTS11QQSKJDQCVYDFTO3TNMDO0Q
# CLIENT_SECRET:SHXP4EQPMHICO3EODBF2HYEOR4RWHOWJ5FMCRS0BAUYNIU0H

# %% [markdown]
# Next, we pick a search radius for venues and create a function to retrieve a dataframe with venues nearby each point:

# %%
LIMIT = 100 
radius = 500

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url3 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url3).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# We call the function with the points in the fatal accidents dataset:

# %%
sl_close_venues = getNearbyVenues(names=df_wknd['OBJECTID'],
                                   latitudes=df_wknd['Latitude'],
                                   longitudes=df_wknd['Longitude']
                                  )
# Out:
# 715213
# 717337
# 718353
# 718780
# 719435
# 720486
# 721169
# 721672
# 722205
# 722653
# 726644
# 727092
# 727821
# 732135
# 732570
# 733000
# 734021
# 739479
# 741512
# 742075
# 742294
# 748689
# 749726
# 756101

# %% [markdown]
# Each ID will get nearby locations. We apply one-hot encoding for each venue type and define a function to group 10 most common venue category close to each point:

# %%
# one hot encoding
med_onehot = pd.get_dummies(sl_close_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
med_onehot['Neighborhood'] = sl_close_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [med_onehot.columns[-1]] + list(med_onehot.columns[:-1])
med_onehot = med_onehot[fixed_columns]

med_grouped = med_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = med_grouped['Neighborhood']

for ind in np.arange(med_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(med_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#     Neighborhood 1st Most Common Venue   2nd Most Common Venue  \
# 0         715213           Bus Station                    Park
# 1         717337                   Bar            Dessert Shop
# 2         718353                  Café             Pizza Place
# 3         718780          Burger Joint             Pizza Place
# 4         719435                Bakery                    Café
# 5         720486                   Bar      Italian Restaurant
# 6         721169         Grocery Store               BBQ Joint
# 7         721672  Gym / Fitness Center           Shopping Mall
# 8         722205                 Plaza        Department Store
# 9         722653          Soccer Field  Argentinian Restaurant
# 10        726644      Pedestrian Plaza                    Park
# 11        727092                  Café             Pizza Place
# 12        727821          Burger Joint             Pizza Place
# 13        732135             Cable Car                    Café
# 14        732570               Airport            Burger Joint
# 15        733000                   Bar            Dessert Shop
# 16        734021                   Gym           Shopping Mall
# 17        739479      Airport Terminal           Shopping Mall
# 18        741512         Metro Station        Pedestrian Plaza
# 19        742075        Clothing Store            Home Service
# 20        742294           Pizza Place          Sandwich Place
# 21        748689            Restaurant        Pedestrian Plaza
# 22        749726        Sandwich Place                     Gym
# 23        756101             Nightclub          Ice Cream Shop
#
#          3rd Most Common Venue 4th Most Common Venue  \
# 0   Construction & Landscaping           Supermarket
# 1   Construction & Landscaping            Public Art
# 2          Housing Development        Farmers Market
# 3                    Bookstore            Restaurant
# 4         Colombian Restaurant    Italian Restaurant
# 5                   Restaurant        Sandwich Place
# 6                   Sports Bar         Hot Dog Joint
# 7                         Park   Fried Chicken Joint
# 8                    Wine Shop              Dive Bar
# 9                  Bus Station  Colombian Restaurant
# 10                         Bar                 Plaza
# 11              Sandwich Place                Bakery
# 12                   BBQ Joint                  Café
# 13              Clothing Store           Coffee Shop
# 14                         Pub                 Plaza
# 15                   BBQ Joint            Public Art
# 16                  Steakhouse               Gay Bar
# 17         Fried Chicken Joint        Sandwich Place
# 18                     Theater                  Park
# 19  Construction & Landscaping            Art Museum
# 20               Burrito Place  Fast Food Restaurant
# 21                       Hotel                  Park
# 22                   Pet Store          Burger Joint
# 23              Sandwich Place             BBQ Joint
#
#         5th Most Common Venue      6th Most Common Venue  \
# 0                   Wine Shop             Discount Store
# 1           Recreation Center                  BBQ Joint
# 2   Latin American Restaurant                 Restaurant
# 3   Latin American Restaurant                        Bar
# 4                   BBQ Joint             Sandwich Place
# 5                       Hotel                       Café
# 6              Cosmetics Shop                      Diner
# 7               Big Box Store                Coffee Shop
# 8              Clothing Store                Coffee Shop
# 9              Farmers Market               Intersection
# 10                Art Gallery                    Theater
# 11         Italian Restaurant                 Restaurant
# 12         Italian Restaurant                     Bakery
# 13       Colombian Restaurant    Comfort Food Restaurant
# 14             Sandwich Place                 Donut Shop
# 15          Recreation Center                  Wine Shop
# 16             Clothing Store       Gym / Fitness Center
# 17                        Pub                Pizza Place
# 18                Pastry Shop             Clothing Store
# 19                   Dive Bar                 Donut Shop
# 20                Coffee Shop               Burger Joint
# 21             Clothing Store  Latin American Restaurant
# 22             Hardware Store                       Café
# 23                        Gym                       Café
#
#          7th Most Common Venue    8th Most Common Venue  \
# 0               Clothing Store              Coffee Shop
# 1             Asian Restaurant                Wine Shop
# 2         Colombian Restaurant             Intersection
# 3                       Bakery      Housing Development
# 4                    Nightclub                     Park
# 5                  Pizza Place                BBQ Joint
# 6                 Dessert Shop         Department Store
# 7         Colombian Restaurant  Comfort Food Restaurant
# 8         Colombian Restaurant  Comfort Food Restaurant
# 9                         Café        French Restaurant
# 10                  Restaurant                    Hotel
# 11                Burger Joint   Argentinian Restaurant
# 12               Shopping Mall             Soccer Field
# 13  Construction & Landscaping        Convenience Store
# 14              Cosmetics Shop               Shoe Store
# 15              Cosmetics Shop         Department Store
# 16          Italian Restaurant        Food & Drink Shop
# 17                       Plaza              Coffee Shop
# 18               Big Box Store          Bed & Breakfast
# 19                 Coffee Shop     Colombian Restaurant
# 20         Rental Car Location       Mexican Restaurant
# 21          Italian Restaurant           Scenic Lookout
# 22                  Restaurant                   Bistro
# 23              Clothing Store                Juice Bar
#
#          9th Most Common Venue      10th Most Common Venue
# 0         Colombian Restaurant     Comfort Food Restaurant
# 1                     Creperie                       Diner
# 2                          Bar                      Bakery
# 3           Italian Restaurant      Argentinian Restaurant
# 4                    Juice Bar                    Creperie
# 5               Ice Cream Shop                   Nightclub
# 6                     Creperie           Convenience Store
# 7   Construction & Landscaping           Convenience Store
# 8   Construction & Landscaping           Convenience Store
# 9                   Food Court              Clothing Store
# 10                   Wine Shop           Convenience Store
# 11                   Bookstore                Soccer Field
# 12     Comfort Food Restaurant                  Restaurant
# 13              Cosmetics Shop                    Creperie
# 14               Shopping Mall                      Bakery
# 15                    Creperie  Construction & Landscaping
# 16              Sandwich Place          Mexican Restaurant
# 17             Airport Service        Colombian Restaurant
# 18                       Hotel                         Bar
# 19     Comfort Food Restaurant           Convenience Store
# 20             Bed & Breakfast                        Food
# 21                 Beer Garden               Indie Theater
# 22               Bowling Alley                 Pizza Place
# 23                  Eye Doctor                   Multiplex

# %% [markdown]
# As we can see, out of the 24 fatal accident locations, there are only three where the closest venue are bars, and there is only one point where the closest venue is a Nightclub.
#
# This doesn't bring any strong evidence that these incidents might be caused by drunk drivers. Moreover, even if the driver was in fact drunk, the accident location might not be close to the point where the person got drunk, or the driver could have drunk in a different place, not a bar or nightclub. More data needs to be retrieved in order to have a deeper understanding of the possible causes of each accident.

# %% [markdown]
# # Part 2: Traffic accidents and speed cameras

# %% [markdown]
# In the second part of this exercise, we will use a second dataset, which has the coordinates of all the traffic enforcement cameras (speed cameras) in the city

# %%
url="https://www.datos.gov.co/resource/js6n-qi6v.csv"
df=pd.read_csv(url)
df.columns=["Id", "Address", "Max Speed", "Longitude", "Latitude", "Coordinates"]
df=df.drop(columns=['Id'])
df.head()
# Out:
#            Address  Max Speed  Longitude  Latitude  \
# 0      Cr 49 Cl 18         80 -75.576640  6.220000
# 1      Cr 80 Cl 55         60 -75.595299  6.269409
# 195    749500   4:50:00PM          Choque  MUERTO  MARTES    -75.648904
# 196    749726  10:49:00PM          Choque  MUERTO  DOMINGO   -75.577322
# 197    752909   5:47:00PM       Atropello  MUERTO  MARTES    -75.571639
# 198    751039   9:45:00AM       Atropello  MUERTO  MIERCOLES -75.563712
# 199    751153   7:26:00PM          Choque  MUERTO  VIERNES   -75.576737
# 200    751659   7:20:00AM          Choque  MUERTO  DOMINGO   -75.578615
# 201    751848   7:40:00PM            Otro  MUERTO  DOMINGO   -75.611865
# 202    752032   9:20:00AM  Caida Ocupante  MUERTO  LUNES     -75.584166
# 203    752219   7:00:00PM       Atropello  MUERTO  DOMINGO   -75.591542
# 204    755936  11:33:00AM          Choque  MUERTO  MIERCOLES -75.561467
# 205    756068   5:10:00PM          Choque  MUERTO  DOMINGO   -75.575700
# 206    756101   2:00:00AM          Choque  MUERTO  SABADO    -75.568825
# 207    756244   1:20:00AM       Atropello  MUERTO  LUNES     -75.568541
# 208    756434   5:20:00PM       Atropello  MUERTO  SABADO    -75.564400
# 209    756620  12:20:00PM          Choque  MUERTO  DOMINGO   -75.609242
# 210    757927   1:01:00PM          Choque  MUERTO  SABADO    -75.591324
# 211    758337   6:13:00AM          Choque  MUERTO  VIERNES   -75.587846
# 212    758459   7:43:00AM          Choque  MUERTO  MARTES    -75.597720
# 213    757171   7:50:00PM  Caida Ocupante  MUERTO  LUNES     -75.549805
# 214    757341   5:00:00AM          Choque  MUERTO  MARTES    -75.534081
# 215    757505   1:50:00PM     Volcamiento  MUERTO  MARTES    -75.570452
# 216    757615   7:50:00AM          Choque  MUERTO  MIERCOLES -75.558307
#
#      Latitude
# 0    6.203833
# 1    6.270420
# 2    6.273293
# 3    6.273796
# 4    6.249833
# 5    6.225350
# 6    6.262900
# 7    6.272931
# 8    6.271095
# 9    6.280594
# 10   6.226612
# 11   6.246798
# 12   6.255602
# 13   6.295546
# 14   6.285445
# 15   6.270336
# 16   6.273480
# 17   6.271949
# 18   6.289219
# 19   6.264761
# 20   6.231316
# 21   6.234832
# 22   6.253410
# 23   6.279281
# 24   6.251071
# 25   6.256743
# 26   6.230935
# 27   6.250245
# 28   6.274572
# 29   6.255019
# 30   6.251856
# 31   6.295117
# 32   6.197951
# 33   6.245462
# 34   6.224149
# 35   6.208377
# 36   6.252683
# 37   6.259827
# 38   6.249053
# 39   6.224406
# 40   6.253004
# 41   6.287877
# 42   6.306491
# 43   6.250500
# 44   6.231106
# 45   6.273563
# 46   6.231884
# 47   6.257120
# 48   6.232295
# 49   6.255711
# 50   6.301392
# 51   6.258539
# 52   6.264249
# 53   6.289219
# 54   6.269760
# 55   6.268537
# 56   6.208779
# 57   6.230455
# 58   6.283407
# 59   6.257700
# 60   6.231884
# 61   6.227300
# 62   6.210383
# 63   6.188241
# 64   6.231856
# 65   6.242700
# 66   6.306530
# 67   6.231148
# 68   6.252510
# 69   6.254400
# 70   6.299935
# 71   6.280594
# 72   6.192284
# 73   6.256650
# 74   6.302098
# 75   6.251192
# 76   6.239518
# 77   6.199519
# 78   6.194812
# 79   6.260460
# 80   6.259593
# 81   6.253392
# 82   6.303258
# 83   6.243250
# 84   6.217813
# 85   6.263734
# 86   6.234524
# 87   6.247087
# 88   6.252555
# 89   6.201141
# 90   6.277925
# 91   6.258709
# 92   6.229405
# 93   6.216870
# 94   6.290313
# 95   6.217029
# 96   6.245048
# 97   6.195851
# 98   6.288415
# 99   6.246681
# 100  6.303432
# 101  6.208415
# 102  6.263142
# 103  6.262004
# 104  6.268011
# 105  6.252706
# 106  6.299178
# 107  6.228285
# 108  6.288678
# 109  6.304481
# 110  6.174669
# 111  6.282312
# 112  6.207886
# 113  6.225350
# 114  6.221901
# 115  6.272575
# 116  6.273830
# 117  6.245280
# 118  6.265374
# 119  6.172713
# 120  6.211037
# 121  6.265892
# 122  6.261934
# 123  6.255919
# 124  6.286452
# 125  6.280594
# 126  6.254938
# 127  6.246984
# 128  6.172949
# 129  6.213966
# 130  6.174669
# 131  6.242655
# 132  6.271767
# 133  6.255095
# 134  6.241864
# 135  6.280293
# 136  6.226344
# 137  6.220072
# 138  6.246798
# 139  6.283327
# 140  6.243879
# 141  6.264451
# 142  6.244529
# 143  6.183269
# 144  6.272214
# 145  6.251096
# 146  6.244329
# 147  6.280494
# 148  6.276728
# 149  6.206569
# 150  6.254449
# 151  6.251691
# 152  6.256976
# 153  6.258204
# 154  6.197712
# 155  6.244171
# 156  6.174915
# 157  6.231884
# 158  6.265110
# 159  6.229667
# 160  6.294318
# 161  6.295513
# 162  6.254800
# 163  6.243879
# 164  6.173049
# 165  6.234513
# 166  6.280388
# 167  6.272979
# 168  6.294318
# 169  6.274009
# 170  6.288343
# 171  6.290406
# 172  6.240648
# 173  6.257521
# 174  6.311422
# 175  6.211126
# 176  6.234818
# 177  6.264832
# 178  6.280840
# 179  6.195598
# 180  6.200470
# 181  6.292963
# 182  6.288685
# 183  6.211265
# 184  6.240020
# 185  6.292199
# 186  6.245495
# 187  6.246992
# 188  6.307885
# 189  6.185285
# 190  6.232839
# 191  6.250141
# 192  6.258244
# 193  6.303432
# 194  6.266721
# 195  6.292726
# 196  6.213905
# 197  6.254431
# 198  6.242971
# 199  6.207612
# 200  6.252662
# 201  6.271860
# 202  6.284432
# 203  6.234470
# 204  6.303390
# 205  6.218632
# 206  6.228088
# 207  6.249768
# 208  6.246786
# 209  6.253380
# 210  6.228419
# 211  6.225195
# 212  6.258838
# 213  6.266908
# 214  6.230891
# 215  6.289219
# 216  6.271772

# %%
map_med = folium.Map(location=[latitude, longitude], zoom_start=12.5)

# add markers to map
for lat, lng, adrs, max_speed in zip(df['Latitude'], df['Longitude'], df['Address'], df['Max Speed']):
    label = '{}, {}'.format(adrs, max_speed)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(map_med)  
    
for lt, lg, cls, day, time in zip(df3['Latitude'], df3['Longitude'], df3['CLASS'], df3['DAY'], df3['TIME']):
    label = '{}, {}, {}'.format(cls, day, time)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lt, lg],
        radius=3,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(map_med) 
    
map_med
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
